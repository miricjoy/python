# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name):
    print("Hello, " + name)

# colon missing

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + str(age) + " years old")

#typecast age to str datatype
# Out:
# I am 25 years old

# %%
#3.Question:
#What is the issue with the following code?

def greet():
    message = "Hello"
    print(message)

#follow tab space within function definition

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b=5):
    return a + b

print(add(5))
#add default value to b

#or
# Out:
# 10

# %%
#pass  two values as parameters
def add(a, b):
    return a + b

print(add(5,3))
# Out:
# 8

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False

is_even(4)
# even numbers are divisible by 2,reminder=0
# Out:
# True

# %%
#6.What happens when you run this code?

num = int("10")
print(num)

#10a--a is not a integer
# Out:
# 10

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort()
print(numbers)
numbers.reverse()
print(numbers)

#numbers.sort() just sorts the numbers in ascending order and stores the result in original memory location
#numbers.reverse()- reverse the order
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?


count = 10 #global variable

def increment(count): #now count can be accessed inside function
    count += 1
    print(count)

increment(count) #pass it as argument
# Out:
# 11

# %%
#10.What error will occur in the following code?

#text = "Python"
#print(text[10])

#string index out of range
text = "Python"
print(text[0:])


#index from 0 to 5
# Out:
# Python
