# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = int("5")
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[3])

#list index out of range - indexing starts from 0, so the list has 0,1,2,3 indices
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
#division by 0 gives answer as infinity
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
print("Name: " , name , ", Age: " ,age)

#instead of + use ,
# Out:
# Name:  Alice , Age:  25

# %%
#8.Find the error
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x == 5:
    print("x is 5")

# == sign missing

# %%
#10. Identify the error in the following function definition:

def greet(name):
    print("Hello, " + name)

# %%
greet("miriam")
# Out:
# Hello, miriam
